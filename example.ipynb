# %%
# 更新 duckdb 中的 index、shenwan 表
# index 中存储 ChinaA、沪深300、中证500、中证1000 指数成分股
# shenwan 中存储股票申万行业信息

from database.index import update_index
from database.shenwan import update_shenwan
update_index()
update_shenwan()

# %%
from database import csi, shenwan

print("获取A股所有上市公司列表")
print(csi.query(csi_name="ChinaA"))
print("获取所有股票申万行业信息")
print(shenwan.query())

# %%
from database import stock
print("列出最近两年上市的新股")
print(stock.list_new_stocks())

print("查询瑞芯微所有股票数据")
print(stock.query(symbol="sh603893"))

# %%
from database import fq

print("查询瑞芯微复权股票数据")
print(fq(symbol="sh603893"))
